# %% [markdown]
# <br><br><br>
# <h1><font color="#B30033" size=5>Sistemas Inteligentes - Curso 2023-2024</font></h1>
#
#
#
# <h1><font color="#B30033" size=5>Práctica 1: Búsqueda en espacio de estados</font></h1>
#
#
# <br>
# <div estilo="text-align: izquierda">
# <font color="#4E70BE" size=3>Profesores:</font><br>
# <ul>
# <li><font color="#4E70BE" size=3>Juan Carlos Alfaro Jiménez (JuanCarlos.Alfaro@uclm.es)</font><br></li>
# <li><font color="#4E70BE" size=3>Mª Julia Flores Gallego (Julia.Flores@uclm.es)</font><br></li>
# <li><font color="#4E70BE" size=3> Luna Jimenéz Fernández (Luna.Jimenez@uclm.es)</font><br></li>
# <li><font color="#4E70BE" size=3> Ismael García Varea (Ismael.Garcia@uclm.es)</font><br></li>
# <li><font color="#4E70BE" size=3> Luis González Naharro (Luis.GNaharro@uclm.es)</font>
# <li><font color="#4E70BE" size=3> Marina Sokolova (Marina .Sokolova@uclm.es)</font>
# <br></li>
# </ul>
# </div>

# %% [markdown]
# <br>
# <div estilo="text-align: izquierda">
# <font color="#4E70BE" size=3>Alumnos:</font><br>
# <ul>
# <li><font color="#4E70BE" size=3>Sergio González Velasco (Sergio.Gonzalez35@alu.uclm.es)</font><br></li>
# <li><font color="#4E70BE" size=3>Minerva Jiménez Álvarez (Minerva.Jimenez@alu.uclm.es)</font><br></li>
#
# <br></li>
# </ul>
# </div>

# %% [markdown]
# # ¡Rescate Urbano!

# %% [markdown]
# ## 1. Introducción
#
#
# En esta tarea, se presenta una situación de rescate urbano simulada donde deberéis desarrollar un sistema de inteligencia artificial para ayudar a un equipo de rescate a encontrar la ruta más rápida y segura para rescatar a personas atrapadas en varios lugares de una ciudad después de un desastre natural. La ciudad está representada por una cuadrícula donde cada celda puede tener diferentes estados: bloqueada, libre, con personas atrapadas o con peligros. Los equipos de rescate deben considerar tanto la velocidad como la seguridad durante la búsqueda.
#
# ### Objetivos:
#
# - Implementar estrategias de búsqueda no informada (búsqueda primero en anchura y primero en profundidad) para encontrar un camino desde el punto de partida hasta un lugar de rescate.
# - Implementar estrategias de búsqueda informada (A* y búsqueda voraz) utilizando heurísticas apropiadas para optimizar la ruta de rescate considerando el tiempo y la seguridad.
#
#
# En este trabajo pondremos en práctica las técnicas de búsqueda en estado de espacios. Para ello, se implementarán y utilizarán algunos de los algoritmos vistos en los temas dos y tres para resolver un problema clásico: buscar rutas en una cuadrícula.
#
# También analizaremos y compararemos el rendimiento de los algoritmos ejecutándolos en diferentes instancias del problema y proporcionando distintos estados inicial y objetivo.
#
# Esperamos que esta práctica os ayude a profundizar en vuestra comprensión de las estrategias de búsqueda en inteligencia artificial y os anime a pensar en cómo se pueden aplicar estas técnicas en situaciones del mundo real para ayudar en operaciones de rescate y otras tareas críticas. ¡Buena suerte!

# %% [markdown]
# ## 2. Descripción del problema
#
# Deberéis resolver un problema en el que un robot tiene que encontrar la ruta más corta a varios puntos de rescate en una cuadrícula, evitando obstáculos y zonas peligrosas. El espacio de búsqueda está definido por una cuadrícula donde el robot puede moverse en cuatro direcciones: arriba, abajo, izquierda y derecha.
#
# Más formalmente, el problema se puede definir como:
# - Estado inicial: Un punto de partida en la cuadrícula que representa la base de los equipos de rescate.
# - Estados:
#   - Libre: Los equipos pueden pasar sin problemas.
#   - Bloqueado: Celdas intransitables debido a obstáculos como escombros o inundaciones.
#   - Personas atrapadas: Localizaciones donde se encuentran grupos de personas que necesitan ser rescatadas.
#   - Peligros: Áreas con peligros adicionales que pueden retrasar el rescate o incrementar el coste de la ruta (por ejemplo, incendios, áreas inestables, etc.).
#   - Estado final: Haber rescatado a todas las personas atrapadas.
#   - Acciones: moverse a una celda adyacente (arriba, abajo, izquierda, derecha) desde la celda actual.

# %% [markdown]
# ### 2.1 Ejemplo ilustrativo:
#
# Un posible ejemplo de este problema podría ser el que se muestra aquí:
#
# <img src="./Figure_1.png" alt="Simple example" width="500" height="500"/>
#
# Nota: recuerda incluir el archivo de imagen en la misma carpeta que el cuaderno, si no lo has hecho ya.

# %% [markdown]
# ## 3. Desarrollo de tareas
#
# Durante el desarrollo de la tarea, se te entregará un conjunto de instancias de problemas. La dimensionalidad, tanto en el número como en el tipo de celdas, será variable, y tus algoritmos deberán ser lo suficientemente eficientes para funcionar correctamente en todas las instancias. Algunos otros escenarios se mantendrán aparte para la evaluación/corrección/entrevista, así que deberás escribir código que sea lo suficientemente general como para cargarlos fácilmente.

# %% [markdown]
# ### 3.1 Problemas de entrada
#
# Cada escenario tendrá asociado un archivo JSON con la siguiente estructura:
#
# ```JSON
# {
#     "city": {
#         "rows": number_of_rows,
#         "columns": number_of_columns,
#         "blocked": [[x_b1,y_b1],...,[x_bn,y_bn]]
#         },
#     "departure": [x_init,y_init],
#     "dangers": [[x_d1,y_d1],...,[x_dk, y_dk]],
#     "trapped": [[x_t1,y_t1],...,[x_tm, y_tm]]
# }
# ```
#
# Hay cuatro claves generales en el archivo JSON:
# - `city`: Un diccionario que representa la cuadrícula del problema.
# - `departure`: La celda de inicio, es decir, la ubicación inicial del robot.
# - `dangers`: Un array con las celdas donde existe un peligro.
# - `trapped`: Un array con las celdas donde hay personas atrapadas que el robot tiene que ir a rescatar.
#
# En el diccionario `city`, hay tres claves:
# - `rows`: El número de filas de la cuadrícula.
# - `columns`: El número de columnas de la cuadrícula.
# - `blocked`: Un array con las celdas por donde el robot no puede cruzar.
#
# Cada celda de la cuadrícula se define como una tupla (x,y) (observa que en formato JSON se representa como una lista de dos números [x,y]):
# - `x`: la coordenada x de la celda o la fila de la cuadrícula.
# - `y`: la coordenada y de la celda o la columna de la cuadrícula.
#
# Asumimos que la celda de la esquina superior izquierda es (0,0), y para una celda determinada (x,y), ten en cuenta que el eje `x` crece hacia abajo (filas) y el eje `y` crece de izquierda a derecha (columnas). Por ejemplo, en la imagen dada el estado inicial sería (3,2). Y la esquina inferior derecha será (9,9), la esquina inferior izquierda será (9,0) y la esquina superior derecha será (0,9).
#
# NOTA: En otras aplicaciones (procesamiento de imágenes) estas coordenadas se suelen dar intercambiadas (x horizointal/columnas e y vertical/filas), pero este sistema facilitará tu trabajo al utilizar listas 2D (matrices) en Python.

# %% [markdown]
# ## 4. Plan de trabajo
#
# Deberás realizar las siguientes tareas:
# - Diseño del espacio de estados:
#   - Describir cómo se representará el espacio de estados, las acciones y el coste de las acciones.
# - Implementación de estrategias de búsqueda:
#   - Implementar al menos dos estrategias de búsqueda no informada para encontrar rutas de rescate.
#   - Implementar al menos dos estrategias de búsqueda informada, utilizando heurísticas adecuadas para encontrar rutas óptimas.
# - Experimentación y análisis:
#   - Analizar el rendimiento de las estrategias implementadas en términos de optimización de tiempo, espacio y rutas.
#   - Comparar y contrastar los resultados obtenidos de las diferentes estrategias de búsqueda.
# - Informe:
#   - Redactar un informe detallando el proceso seguido, las estrategias implementadas y los resultados obtenidos.
#
#
# En la evaluación del trabajo tendremos en cuenta:
# - Correcta implementación de estrategias de búsqueda: 50%.
# - Diseño adecuado del espacio de estados y heurísticas: 20%.
# - Experimentación y análisis de resultados: 20%.
# - Calidad del informe: 10%.
#
# Fechas de presentación de Lab1:
# - Fecha límite para enviar el código: **Viernes 10 de noviembre de 2023**.
# - Plazo de presentación del informe: Posteriormente, junto con Lab2.
#
# A continuación se proporcionan más detalles de cada tarea.

# %% [markdown]
# ### 4.1 Formalización del problema y ejemplos
#
# En primer lugar, la búsqueda de caminos en cuadrículas debe formalizarse como un problema de búsqueda en espacio de estados, definiendo sus elementos básicos. Todas las implementaciones deben hacer referencia a la búsqueda en grafos, por lo que es importante tener en cuenta que se deben controlar los estados repetidos.

# %% [markdown]
# ### 4.2 Implementación
#
# A continuación, deberás implementar el código en Python. Tendrás que codificar tu propia estructura de clases para la formalización del problema y luego implementar los algoritmos estudiados en las clases de teoría para resolver el problema.

# %%
import json
from abc import abstractmethod, ABC
import time
from queue import PriorityQueue


# Clase que inicializa el problema
class Problema:
    def __init__(self, problema_json):
        # Bloque de código encargado de cargar el json que ha sido recibido como parámetro
        with open(problema_json, 'r') as f:
            ciudad = json.load(f)
        # Inicializamos los datos del problema y los almacenamos en variables
        self.filas = ciudad['city']['rows']
        self.columnas = ciudad['city']['columns']
        self.inicio = Nodo(Estado(ciudad['departure'][0], ciudad['departure'][1]))
        self.bloqueados = set(map(tuple, ciudad['city']['blocked']))
        self.peligros = set(map(tuple, ciudad['dangers']))
        self.destinos = set(map(tuple, ciudad['trapped']))
        self.personas_rescatadas = 0
        self.media_nodos_generados = 0.0
        self.media_nodos_expandidos = 0.0
        self.media_tiempo_ejecucion = 0.0
        self.media_tamaño_solucion = 0.0
        self.media_coste_solucion = 0.0

    # Verifica si ese estado es de peligro
    def es_peligro(self, estado):
        return (estado.fila, estado.columna) in self.peligros

    # Verifica si ese estado está bloqueado
    def es_bloqueado(self, estado):
        return (estado.fila, estado.columna) in self.bloqueados

    # Verifica si es un estado válido, se usará para generar los sucesores y que el agente no se salga de los límites
    def es_valido(self, estado):
        return 0 <= estado.fila < self.filas and 0 <= estado.columna < self.columnas and not self.es_bloqueado(estado)

    def heuristica_manhattan(self, nodo_origen, nodo_destino):
        return abs(nodo_origen.estado.fila - nodo_destino.estado.fila) + abs(
            nodo_origen.estado.columna - nodo_destino.estado.columna)

    # Generamos las estadísticas globales tras el rescate de todas las personas y las reseteamos para poder usar otro algoritmo
    def estadisticas_globales(self):
        print("Final statistics")
        print("----------------")
        print("Number of rescued people:", self.personas_rescatadas, "of", len(self.destinos))
        print("Mean number of generated nodes:", (self.media_nodos_generados / len(self.destinos)))
        print("Mean number of expanded nodes:", (self.media_nodos_expandidos / len(self.destinos)))
        print("Mean execution time:", (self.media_tiempo_ejecucion / len(self.destinos)))
        print("Mean solution length:", (self.media_tamaño_solucion / len(self.destinos)))
        print("Mean solution cost:", (self.media_coste_solucion / len(self.destinos)))
        print(" ")
        self.resetear_estadisticas()

    # Método usado para resetear las estadísticas
    # Debemos de hacerlo si queremos aplicar otro algoritmo
    def resetear_estadisticas(self):
        self.personas_rescatadas = 0
        self.media_nodos_generados = 0.0
        self.media_nodos_expandidos = 0.0
        self.media_tiempo_ejecucion = 0.0
        self.media_tamaño_solucion = 0.0
        self.media_coste_solucion = 0.0

    def resolver_anchura(self, nodos_rescate):
        print("---ALGORITMO EN ANCHURA---")
        for persona_rescate in nodos_rescate:
            Anchura(problema).iniciar_busqueda(persona_rescate)
        self.estadisticas_globales()

    def resolver_profundidad(self, nodos_rescate):
        print("---ALGORITMO EN PROFUNDIDAD---")
        for persona_rescate in nodos_rescate:
            Profundidad(problema).iniciar_busqueda(persona_rescate)
        self.estadisticas_globales()

    # Parte extraordinaria
    def resolver_profundidad_limitada(self, nodos_rescate, prof_max):
        print("---ALGORITMO EN PROFUNDIDAD LIMITADA---")
        for persona_rescate in nodos_rescate:
            Profundidad(problema).iniciar_busqueda_limitada(persona_rescate, prof_max)
        self.estadisticas_globales()

    def resolver_profundidad_iterativa(self, nodos_rescate):
        print("---ALGORITMO EN PROFUNDIDAD ITERATIVA---")
        for persona_rescate in nodos_rescate:
            prof_max = 1
            sol = Profundidad(problema).iniciar_busqueda_limitada(persona_rescate, prof_max)
            if sol == -1:
                while sol == -1:
                    prof_max += 1
                    #print("Aumentando profundidad en ", 1,"profundidad actual: ", prof_max)
                    #print(" ")
                    sol = Profundidad(problema).iniciar_busqueda_limitada(persona_rescate, prof_max)
        problema.estadisticas_globales()
        #print("Profundidad máxima alcanzada ", profundidad_maxima)

    def resolver_primero_el_mejor(self, nodos_rescate):
        print("---ALGORITMO PRIMERO EL MEJOR ---")
        for persona_rescate in nodos_rescate:
            PrimeroElMejor(problema).iniciar_busqueda(persona_rescate)
        self.estadisticas_globales()

    def resolver_A_estrella(self, nodos_rescate):
        print("---ALGORITMO AESTRELLA---")
        for persona_rescate in nodos_rescate:
            AEstrella(problema).iniciar_busqueda(persona_rescate)
        self.estadisticas_globales()


# Clase en la que definimos el estado
class Estado:
    def __init__(self, fila, columna):
        self.fila = fila
        self.columna = columna

    def __eq__(self, otro):
        return (self.fila, self.columna) == (otro.fila, otro.columna)

    # Usado para comprobar si un estado es o no destino en el método iniciar_busqueda
    def __hash__(self):
        return hash((self.fila, self.columna))

    def __repr__(self):
        return str(f"(fila {self.fila}, columna {self.columna})")


# Clase encargada de realizar la acción y el coste de ella misma
class Accion:
    def __init__(self, estado, accion, ciudad):
        self.coste = self.calcular_coste(estado, ciudad)
        self.accion = accion

    def calcular_coste(self, estado, ciudad):
        if not ciudad.es_peligro(estado):
            coste = 1
        else:
            coste = 5
        return coste


# Clase en la que definimos un Nodo
# En función de si el nodo es raíz, tendrá padre así como la acción por la que se ha llegado al nodo
class Nodo:
    def __init__(self, estado, accion=None, padre=None, nid=0):
        self.estado = estado
        self.padre = padre
        self.coste = accion.coste + padre.coste if padre is not None else 0  # Hecho en tutoria con Juan Carlos
        self.profundidad = padre.profundidad + 1 if padre is not None else 0  # Hecho en tutoria con Juan Carlos
        self.accion = accion
        self.id = nid

    def __eq__(self, otro):
        return hash(self.estado) == hash(otro)

    # Hecho en tutoria con Juan Carlos
    def __lt__(self, otro):
        return self.id < otro.id

    # Usado para la búsqueda informada para iterar en PriorityQueue
    def __hash__(self):
        return hash(self.estado)


# Clase genérica Search que se usará como herencia para los distintos tipos de algoritmos
class Search(ABC):
    @abstractmethod
    def insertar_nodo(self, nodo, nodo_lista):
        pass

    @abstractmethod
    def extraer_nodo(self, nodo_lista):
        pass

    @abstractmethod
    def comprobar_vacio(self, nodo):
        pass

    def __init__(self, ciudad):
        self.ciudad = ciudad
        self.tiempo_ejecucion = None
        self.nodos_cerrados = set()
        self.nodos_abiertos = None  # En función del algoritmo se usará un tipo como nodos abiertos u otros
        self.nodos_expandidos = 0
        self.nodos_generados = 0
        self.coste = 0
        self.rescate_actual = None  # Para el cálculo de la heurística en búsqueda informada PrimeroElMejor y AEstrella

    def generar_sucesores(self, nodo):
        # Posibles movimientos
        movimientos = [(-1, 0), (0, 1), (1, 0), (0, -1)]  # Arriba, derecha, abajo, izquierda
        sucesores = []
        # Realizamos todos los posibles movimientos, si son válidos y no son peligro se almacenan como sucesores
        # Tras generar los sucesores, consideramos el nodo ya expandido
        for mx, my in movimientos:
            nueva_fila = nodo.estado.fila + mx
            nueva_columna = nodo.estado.columna + my
            nuevo_estado = Estado(nueva_fila, nueva_columna)
            if self.ciudad.es_valido(nuevo_estado):
                accion_realizada = Accion(nuevo_estado, self.decodificar_accion((mx, my)), self.ciudad)
                nuevo_nodo = Nodo(nuevo_estado, accion_realizada, nodo, nodo.id + 1)
                sucesores.append(nuevo_nodo)
        self.nodos_expandidos += 1
        return sucesores

    # Método auxiliar para decodificar la acción para los sucesores
    def decodificar_accion(self, accion):
        if accion == (-1, 0):
            return 'UP'
        elif accion == (0, 1):
            return 'RIGHT'
        elif accion == (1, 0):
            return 'DOWN'
        elif accion == (0, -1):
            return 'LEFT'

    # Iniciamos la búsqueda a la persona recibida como parámetro
    # Al encontrar a la persona rescatada recuperamos el camino y generar las estadísticas de este rescate
    # En caso contrario genera sucesores viables y continua la búsqueda

    def iniciar_busqueda(self, rescate):
        self.rescate_actual = rescate  # Para el cálculo de la heurística en búsqueda informada PrimeroElMejor y AEstrella
        iniciar_temporizador = time.perf_counter()
        self.insertar_nodo(self.ciudad.inicio, self.nodos_abiertos)
        print("Rescuing person at position:", (rescate.estado.fila, rescate.estado.columna))
        print("-----------------------------------")
        while not self.comprobar_vacio(self.nodos_abiertos):
            nodo = self.extraer_nodo(self.nodos_abiertos)
            if nodo.estado == rescate.estado:
                self.coste = nodo.coste
                finalizar_temporizador = time.perf_counter()
                self.tiempo_ejecucion = (finalizar_temporizador - iniciar_temporizador)
                camino = self.recuperar_camino(nodo)
                return self.generar_estadisticas(camino)
            else:
                if nodo.estado not in self.nodos_cerrados:  # Requiere que estado tenga hash
                    sucesores = self.generar_sucesores(nodo)
                    for sucesor in sucesores:
                        self.insertar_nodo(sucesor, self.nodos_abiertos)
                self.nodos_cerrados.add(nodo.estado)

    # Nuevo método de búsqueda entrega extraordinaria
    # Funciona similar que el anterior pero con la maxima profundidad adjuntada como parámetro
    # En caso de no encontrar a la persona a una profundidad, se especifica el mensaje de error
    def iniciar_busqueda_limitada(self, rescate, max_profundidad):
        iniciar_temporizador = time.perf_counter()
        self.insertar_nodo(self.ciudad.inicio, self.nodos_abiertos)
        print("Rescuing person at position:", (rescate.estado.fila, rescate.estado.columna))
        print("-----------------------------------")
        while not self.comprobar_vacio(self.nodos_abiertos):
            nodo = self.extraer_nodo(self.nodos_abiertos)
            if nodo.estado == rescate.estado:
                self.coste = nodo.coste
                finalizar_temporizador = time.perf_counter()
                self.tiempo_ejecucion = (finalizar_temporizador - iniciar_temporizador)
                camino = self.recuperar_camino(nodo)
                return self.generar_estadisticas(camino)
            else:
                if nodo.profundidad < max_profundidad and nodo.estado not in self.nodos_cerrados:
                    sucesores = self.generar_sucesores(nodo)
                    for sucesor in sucesores:
                        self.insertar_nodo(sucesor, self.nodos_abiertos)
                self.nodos_cerrados.add(nodo.estado)

            if self.comprobar_vacio(self.nodos_abiertos):
                print("No se ha podido acceder a la persona a la profundidad establecida de ", max_profundidad)
                print(" ")
                return -1

    # Método auxiliar para recuperar el camino tras encontrar a la persona a rescatar
    def recuperar_camino(self, nodo):
        camino = []
        while nodo.padre:
            camino.append(nodo.accion.accion)
            nodo = nodo.padre
        return camino

    # Generamos las estadísticas de una búsqueda tras finalizar y almacenamos dichos datos para las estadísticas globales
    def generar_estadisticas(self, camino):
        print("Generated nodes:", self.nodos_generados)
        print("Expanded nodes:", self.nodos_expandidos)
        print("Execution time:", self.tiempo_ejecucion)
        print("Solution length:", len(camino))
        print("Solution cost:", float(self.coste))
        print("Solution:", list(reversed(camino)))
        print(" ")
        # Actualizamos los datos del problema
        self.ciudad.personas_rescatadas += 1
        self.ciudad.media_nodos_generados += self.nodos_generados
        self.ciudad.media_nodos_expandidos += self.nodos_expandidos
        self.ciudad.media_tiempo_ejecucion += self.tiempo_ejecucion
        self.ciudad.media_tamaño_solucion += len(camino)
        self.ciudad.media_coste_solucion += float(self.coste)


# Algoritmo en anchura
class Anchura(Search):

    def __init__(self, ciudad):
        super().__init__(ciudad)
        self.nodos_abiertos = []

    def insertar_nodo(self, nodo, nodo_lista):
        # Con append nos aseguramos del FIFO necesario con el pop
        nodo_lista.append(nodo)
        self.nodos_generados += 1

    def extraer_nodo(self, nodo_lista):
        return nodo_lista.pop(0)

    def comprobar_vacio(self, nodo_lista):
        return nodo_lista.__len__() == 0


# Algoritmo en profundidad
class Profundidad(Search):

    def __init__(self, ciudad):
        super().__init__(ciudad)
        self.nodos_abiertos = []

    def insertar_nodo(self, nodo, nodo_lista):
        # Si insertamos los nodos en la posicion 0 siempre, nos aseguramos el LIFO necesario con el pop
        nodo_lista.insert(0, nodo)
        self.nodos_generados += 1

    def extraer_nodo(self, nodo_lista):
        return nodo_lista.pop(0)

    def comprobar_vacio(self, nodo_lista):
        return nodo_lista.__len__() == 0


# Algoritmo en profundidad limitada (Extraordinario)
class ProfundidadIterativa(Search):

    def __init__(self, ciudad):
        super().__init__(ciudad)
        self.profundidad_maxima = 1
        self.nodos_abiertos = []

    def insertar_nodo(self, nodo, nodo_lista):
        nodo_lista.insert(0, nodo)
        self.nodos_generados += 1

    def extraer_nodo(self, nodo_lista):
        return nodo_lista.pop(0)

    def comprobar_vacio(self, nodo_lista):
        return nodo_lista.__len__() == 0


# Algoritmo primero el mejor
class PrimeroElMejor(Search):

    def __init__(self, ciudad):
        super().__init__(ciudad)
        self.nodos_abiertos = PriorityQueue()

    def insertar_nodo(self, nodo, nodo_lista):
        heuristica = self.ciudad.heuristica_manhattan(nodo, self.rescate_actual)
        nodo_lista.put((heuristica, nodo))
        self.nodos_generados += 1

    def extraer_nodo(self, nodo_lista):
        nodo = nodo_lista.get()
        return nodo[1]

    def comprobar_vacio(self, nodo_lista):
        return nodo_lista.qsize() == 0


# Algoritmo AEstrella
class AEstrella(Search):

    def __init__(self, ciudad):
        super().__init__(ciudad)
        self.nodos_abiertos = PriorityQueue()

    def insertar_nodo(self, nodo, nodo_lista):
        heuristica = self.ciudad.heuristica_manhattan(nodo, self.rescate_actual)
        nodo_lista.put(((nodo.coste + heuristica), nodo))
        self.nodos_generados += 1

    def extraer_nodo(self, nodo_lista):
        nodo = nodo_lista.get()
        return nodo[1]

    def comprobar_vacio(self, nodo_lista):
        return nodo_lista.qsize() == 0


if __name__ == '__main__':
    # Inicializamos el problema cargando el json y parametrizandolo
    problema = Problema('./problemas/instance-20-20-33-8-33-2023.json')
    profundidad_maxima = 100
    nodos_de_rescate = []
    for persona in problema.destinos:
        nodos_de_rescate.append(Nodo(Estado(persona[0], persona[1])))

    # Resolución de los algoritmos, descomentar según proceda
    problema.resolver_anchura(nodos_de_rescate)
    problema.resolver_profundidad(nodos_de_rescate)
    problema.resolver_profundidad_limitada(nodos_de_rescate, profundidad_maxima)
    problema.resolver_profundidad_iterativa(nodos_de_rescate)
    problema.resolver_primero_el_mejor(nodos_de_rescate)
    problema.resolver_A_estrella(nodos_de_rescate)
# Out:
# ---ALGORITMO EN ANCHURA---
# Rescuing person at position: (14, 4)
# -----------------------------------
# Generated nodes: 52
# Expanded nodes: 14
# Execution time: 0.00025019998429343104
# Solution length: 3
# Solution cost: 3.0
# Solution: ['UP', 'UP', 'LEFT']
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# Generated nodes: 340
# Expanded nodes: 98
# Execution time: 0.0007927000406198204
# Solution length: 9
# Solution cost: 9.0
# Solution: ['UP', 'UP', 'UP', 'UP', 'RIGHT', 'UP', 'UP', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# Generated nodes: 844
# Expanded nodes: 238
# Execution time: 0.002154999994672835
# Solution length: 16
# Solution cost: 24.0
# Solution: ['UP', 'UP', 'UP', 'UP', 'LEFT', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP']
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# Generated nodes: 646
# Expanded nodes: 182
# Execution time: 0.0018764000269584358
# Solution length: 13
# Solution cost: 17.0
# Solution: ['UP', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# Generated nodes: 938
# Expanded nodes: 265
# Execution time: 0.003016800037585199
# Solution length: 17
# Solution cost: 25.0
# Solution: ['UP', 'UP', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# Generated nodes: 874
# Expanded nodes: 247
# Execution time: 0.0020758999744430184
# Solution length: 16
# Solution cost: 20.0
# Solution: ['UP', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# Generated nodes: 465
# Expanded nodes: 133
# Execution time: 0.0010820000316016376
# Solution length: 11
# Solution cost: 11.0
# Solution: ['UP', 'UP', 'UP', 'UP', 'RIGHT', 'UP', 'UP', 'LEFT', 'UP', 'UP', 'RIGHT']
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# Generated nodes: 298
# Expanded nodes: 86
# Execution time: 0.0006691000307910144
# Solution length: 8
# Solution cost: 12.0
# Solution: ['UP', 'UP', 'UP', 'UP', 'LEFT', 'UP', 'UP', 'UP']
#
# Final statistics
# ----------------
# Number of rescued people: 8 of 8
# Mean number of generated nodes: 557.125
# Mean number of expanded nodes: 157.875
# Mean execution time: 0.001489762515120674
# Mean solution length: 11.625
# Mean solution cost: 15.125
#
# ---ALGORITMO EN PROFUNDIDAD---
# Rescuing person at position: (14, 4)
# -----------------------------------
# Generated nodes: 151
# Expanded nodes: 45
# Execution time: 0.00035039999056607485
# Solution length: 37
# Solution cost: 45.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT']
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# Generated nodes: 1182
# Expanded nodes: 338
# Execution time: 0.0032361000194214284
# Solution length: 177
# Solution cost: 221.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'LEFT', 'LEFT', 'LEFT', 'UP', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'UP', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN']
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# Generated nodes: 971
# Expanded nodes: 275
# Execution time: 0.0020975000225007534
# Solution length: 242
# Solution cost: 314.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'LEFT', 'LEFT', 'LEFT', 'UP', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'UP', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT']
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# Generated nodes: 538
# Expanded nodes: 154
# Execution time: 0.0011427999706938863
# Solution length: 137
# Solution cost: 173.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'LEFT', 'LEFT', 'LEFT', 'UP', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN']
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# Generated nodes: 599
# Expanded nodes: 171
# Execution time: 0.0012762999976985157
# Solution length: 153
# Solution cost: 193.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'LEFT', 'LEFT', 'LEFT', 'UP', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN']
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# Generated nodes: 556
# Expanded nodes: 159
# Execution time: 0.0012239000061526895
# Solution length: 142
# Solution cost: 178.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'LEFT', 'LEFT', 'LEFT', 'UP', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'UP']
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# Generated nodes: 737
# Expanded nodes: 211
# Execution time: 0.0017927999724633992
# Solution length: 189
# Solution cost: 233.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'LEFT', 'LEFT', 'LEFT', 'UP', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'UP', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# Generated nodes: 380
# Expanded nodes: 111
# Execution time: 0.0008457000367343426
# Solution length: 98
# Solution cost: 118.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'LEFT', 'LEFT', 'LEFT', 'UP', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT']
#
# Final statistics
# ----------------
# Number of rescued people: 8 of 8
# Mean number of generated nodes: 639.25
# Mean number of expanded nodes: 183.0
# Mean execution time: 0.0014956875020288862
# Mean solution length: 146.875
# Mean solution cost: 184.375
#
# ---ALGORITMO EN PROFUNDIDAD LIMITADA---
# Rescuing person at position: (14, 4)
# -----------------------------------
# Generated nodes: 151
# Expanded nodes: 45
# Execution time: 0.00033840001560747623
# Solution length: 37
# Solution cost: 45.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT']
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# Generated nodes: 600
# Expanded nodes: 171
# Execution time: 0.0014530000044032931
# Solution length: 83
# Solution cost: 107.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT']
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  100
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# Generated nodes: 518
# Expanded nodes: 149
# Execution time: 0.0011931000044569373
# Solution length: 99
# Solution cost: 127.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'UP']
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  100
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  100
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# Generated nodes: 744
# Expanded nodes: 211
# Execution time: 0.0017565999878570437
# Solution length: 91
# Solution cost: 115.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'DOWN']
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# Generated nodes: 380
# Expanded nodes: 111
# Execution time: 0.0008435999625362456
# Solution length: 98
# Solution cost: 118.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'LEFT', 'LEFT', 'LEFT', 'UP', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT']
#
# Final statistics
# ----------------
# Number of rescued people: 5 of 8
# Mean number of generated nodes: 299.125
# Mean number of expanded nodes: 85.875
# Mean execution time: 0.0006980874968576245
# Mean solution length: 51.0
# Mean solution cost: 64.0
#
# ---ALGORITMO EN PROFUNDIDAD ITERATIVA---
# Rescuing person at position: (14, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  1
#
# Rescuing person at position: (14, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  2
#
# Rescuing person at position: (14, 4)
# -----------------------------------
# Generated nodes: 19
# Expanded nodes: 5
# Execution time: 5.1099981646984816e-05
# Solution length: 3
# Solution cost: 3.0
# Solution: ['LEFT', 'UP', 'UP']
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  1
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  2
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  3
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  4
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  5
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  6
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  7
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  8
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  9
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  10
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  11
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  12
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  13
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  14
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  15
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# Generated nodes: 270
# Expanded nodes: 80
# Execution time: 0.0006738000083714724
# Solution length: 15
# Solution cost: 19.0
# Solution: ['RIGHT', 'RIGHT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'UP']
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  1
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  2
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  3
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  4
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  5
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  6
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  7
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  8
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  9
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  10
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  11
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  12
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  13
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  14
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  15
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  16
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  17
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  18
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  19
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  20
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  21
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  22
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  23
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  24
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  25
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  26
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  27
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  28
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  29
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  30
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  31
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  32
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  33
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  34
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  35
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  36
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  37
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  38
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  39
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  40
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  41
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  42
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  43
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  44
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  45
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  46
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  47
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  48
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  49
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  50
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  51
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  52
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  53
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  54
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  55
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  56
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  57
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  58
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  59
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  60
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  61
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  62
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# Generated nodes: 840
# Expanded nodes: 240
# Execution time: 0.002310900017619133
# Solution length: 62
# Solution cost: 86.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'UP', 'LEFT', 'UP', 'UP', 'UP', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'UP', 'RIGHT', 'UP', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'DOWN', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  1
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  2
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  3
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  4
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  5
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  6
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  7
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  8
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  9
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  10
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  11
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  12
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  13
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  14
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  15
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  16
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  17
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  18
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  19
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  20
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  21
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  22
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  23
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  24
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  25
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  26
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  27
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  28
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  29
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  30
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  31
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  32
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# Generated nodes: 297
# Expanded nodes: 86
# Execution time: 0.0008800000068731606
# Solution length: 33
# Solution cost: 33.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'UP', 'LEFT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  1
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  2
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  3
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  4
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  5
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  6
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  7
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  8
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  9
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  10
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  11
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  12
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  13
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  14
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  15
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  16
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  17
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  18
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  19
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  20
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  21
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  22
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  23
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  24
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  25
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  26
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  27
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  28
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  29
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  30
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  31
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  32
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  33
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# Generated nodes: 339
# Expanded nodes: 97
# Execution time: 0.0008121999562717974
# Solution length: 33
# Solution cost: 37.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'UP', 'RIGHT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'RIGHT', 'UP']
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  1
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  2
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  3
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  4
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  5
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  6
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  7
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  8
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  9
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  10
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  11
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  12
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  13
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  14
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  15
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  16
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  17
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  18
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  19
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  20
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  21
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  22
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  23
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  24
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  25
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  26
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  27
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  28
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  29
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  30
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  31
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  32
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  33
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# Generated nodes: 334
# Expanded nodes: 95
# Execution time: 0.0007960000075399876
# Solution length: 32
# Solution cost: 36.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'DOWN', 'DOWN', 'DOWN', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'RIGHT', 'UP', 'UP', 'RIGHT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  1
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  2
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  3
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  4
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  5
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  6
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  7
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  8
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  9
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  10
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  11
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  12
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  13
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  14
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  15
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  16
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  17
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  18
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  19
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  20
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  21
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  22
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  23
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# Generated nodes: 358
# Expanded nodes: 105
# Execution time: 0.000876300036907196
# Solution length: 23
# Solution cost: 31.0
# Solution: ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT', 'UP', 'RIGHT', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'UP', 'UP', 'UP', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  1
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  2
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  3
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  4
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  5
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  6
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  7
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  8
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  9
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  10
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  11
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  12
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# No se ha podido acceder a la persona a la profundidad establecida de  13
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# Generated nodes: 188
# Expanded nodes: 56
# Execution time: 0.00046250002924352884
# Solution length: 14
# Solution cost: 18.0
# Solution: ['LEFT', 'LEFT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'LEFT', 'UP', 'UP', 'LEFT', 'UP', 'UP', 'UP']
#
# Final statistics
# ----------------
# Number of rescued people: 8 of 8
# Mean number of generated nodes: 330.625
# Mean number of expanded nodes: 95.5
# Mean execution time: 0.0008578500055591576
# Mean solution length: 26.875
# Mean solution cost: 32.875
#
# ---ALGORITMO PRIMERO EL MEJOR ---
# Rescuing person at position: (14, 4)
# -----------------------------------
# Generated nodes: 13
# Expanded nodes: 3
# Execution time: 8.38999985717237e-05
# Solution length: 3
# Solution cost: 3.0
# Solution: ['UP', 'UP', 'LEFT']
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# Generated nodes: 31
# Expanded nodes: 9
# Execution time: 0.0001422999775968492
# Solution length: 9
# Solution cost: 9.0
# Solution: ['UP', 'UP', 'UP', 'UP', 'RIGHT', 'UP', 'UP', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# Generated nodes: 61
# Expanded nodes: 16
# Execution time: 0.0005245000356808305
# Solution length: 16
# Solution cost: 24.0
# Solution: ['UP', 'UP', 'UP', 'UP', 'LEFT', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP']
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# Generated nodes: 52
# Expanded nodes: 13
# Execution time: 0.00022159999934956431
# Solution length: 13
# Solution cost: 17.0
# Solution: ['UP', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# Generated nodes: 68
# Expanded nodes: 18
# Execution time: 0.000270900025498122
# Solution length: 17
# Solution cost: 25.0
# Solution: ['UP', 'UP', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# Generated nodes: 64
# Expanded nodes: 16
# Execution time: 0.00023389997659251094
# Solution length: 16
# Solution cost: 20.0
# Solution: ['UP', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# Generated nodes: 41
# Expanded nodes: 12
# Execution time: 0.0001765000051818788
# Solution length: 11
# Solution cost: 11.0
# Solution: ['UP', 'UP', 'UP', 'UP', 'RIGHT', 'UP', 'UP', 'LEFT', 'UP', 'UP', 'RIGHT']
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# Generated nodes: 30
# Expanded nodes: 8
# Execution time: 0.00011580000864341855
# Solution length: 8
# Solution cost: 12.0
# Solution: ['UP', 'UP', 'UP', 'UP', 'LEFT', 'UP', 'UP', 'UP']
#
# Final statistics
# ----------------
# Number of rescued people: 8 of 8
# Mean number of generated nodes: 45.0
# Mean number of expanded nodes: 11.875
# Mean execution time: 0.00022117500338936225
# Mean solution length: 11.625
# Mean solution cost: 15.125
#
# ---ALGORITMO AESTRELLA---
# Rescuing person at position: (14, 4)
# -----------------------------------
# Generated nodes: 21
# Expanded nodes: 5
# Execution time: 0.00011849997099488974
# Solution length: 3
# Solution cost: 3.0
# Solution: ['UP', 'LEFT', 'UP']
#
# Rescuing person at position: (10, 8)
# -----------------------------------
# Generated nodes: 80
# Expanded nodes: 22
# Execution time: 0.00038049998693168163
# Solution length: 9
# Solution cost: 9.0
# Solution: ['RIGHT', 'UP', 'RIGHT', 'UP', 'UP', 'UP', 'UP', 'UP', 'RIGHT']
#
# Rescuing person at position: (1, 4)
# -----------------------------------
# Generated nodes: 170
# Expanded nodes: 47
# Execution time: 0.0008962000138126314
# Solution length: 18
# Solution cost: 18.0
# Solution: ['UP', 'LEFT', 'UP', 'LEFT', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'UP', 'RIGHT']
#
# Rescuing person at position: (14, 16)
# -----------------------------------
# Generated nodes: 127
# Expanded nodes: 32
# Execution time: 0.0005740000051446259
# Solution length: 13
# Solution cost: 13.0
# Solution: ['RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (13, 19)
# -----------------------------------
# Generated nodes: 199
# Expanded nodes: 52
# Execution time: 0.0009438999695703387
# Solution length: 17
# Solution cost: 17.0
# Solution: ['RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'RIGHT']
#
# Rescuing person at position: (14, 19)
# -----------------------------------
# Generated nodes: 156
# Expanded nodes: 40
# Execution time: 0.0007070000283420086
# Solution length: 16
# Solution cost: 16.0
# Solution: ['RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT']
#
# Rescuing person at position: (8, 6)
# -----------------------------------
# Generated nodes: 94
# Expanded nodes: 26
# Execution time: 0.0005357000045478344
# Solution length: 11
# Solution cost: 11.0
# Solution: ['UP', 'UP', 'UP', 'UP', 'RIGHT', 'UP', 'UP', 'LEFT', 'UP', 'UP', 'RIGHT']
#
# Rescuing person at position: (9, 4)
# -----------------------------------
# Generated nodes: 102
# Expanded nodes: 29
# Execution time: 0.0005588000058196485
# Solution length: 10
# Solution cost: 10.0
# Solution: ['UP', 'LEFT', 'UP', 'LEFT', 'UP', 'UP', 'UP', 'UP', 'UP', 'RIGHT']
#
# Final statistics
# ----------------
# Number of rescued people: 8 of 8
# Mean number of generated nodes: 118.625
# Mean number of expanded nodes: 31.625
# Mean execution time: 0.0005893249981454574
# Mean solution length: 12.125
# Mean solution cost: 12.125

# %% [markdown]
# ### 4.3 Estudio y mejora de los algoritmos
#
# Una vez implementados los algoritmos, deberás estudiar su rendimiento. Para ello, debes comparar la calidad de las soluciones obtenidas, así como el número de nodos expandidos para instancias de diferentes tamaños. Factores como el tamaño máximo de problema que se puede resolver (sin que haya desbordamiento de memoria), o el efecto de utilizar escenarios más complejos, también son importantes. Además, puedes proponer implementaciones alternativas que aumenten la eficiencia de los algoritmos.

# %% [markdown]
# ### 4.4 Informe
# Además del cuaderno que contiene la implementación, el trabajo consiste en elaborar un informe, que tendrá una fecha de entrega posterior, pero que deberás empezar a escribir en cuanto el código comience a resolver los problemas correctamente.
#
# En particular, entre otros temas que consideres de interés mencionar, deberá incluir:
#
# - Una breve descripción del problema, una descripción de la implementación, la evaluación del rendimiento y la descripción de las mejoras (si existen).
# - La formalización del problema.
# - Para algoritmos de búsqueda informados se deben proporcionar una (o varias) funciones heurísticas. Además de su descripción y motivación, se deberá incluir un análisis que indique si la heurística propuesta se considera admisible y/o consistente.
# - El estudio del rendimiento de los algoritmos implementados debe basarse en probar los algoritmos en varias instancias, presentando tablas o gráficos que resuman los resultados (¡no incluyas capturas de pantalla!).
#
# El informe no debe incluir figuras con código fuente, a menos que sea necesario para explicar algún concepto clave (estructuras de datos, mejoras en eficiencia, etc). En tales casos, se te permite incluir pseudocódigo con el formato adecuado.

# %% [markdown]
# ## 5. Presentación y evaluación
# Es muy recomendable realizar el trabajo en grupo (por parejas), aunque se puede realizar de forma individual. La fecha límite de presentación es el 10 de noviembre de 2023. Los exámenes orales (entrevistas) para la evaluación se realizarán la semana siguiente y de forma individual.
#
# Algunas consideraciones relacionadas con la evaluación:
# - Este trabajo cuenta un 30% de la nota de laboratorio. Lab2 (70%) necesita la resolución de esta parte. Los envíos fuera de plazo (junto con lab2) o los trabajos suspensos se evaluarán globalmente pero con una penalización del 10%, por lo que sólo podréis obtener el 90% de la nota de laboratorio.
# - La asistencia a las prácticas no es obligatoria, pero será la mejor base para resolver con éxito las prácticas.
# - Recordad que las dudas y preguntas sobre las prácticas de laboratorio deben resolverse principalmente en las sesiones de laboratorio.
# - El trabajo será evaluado durante una entrevista individual (examen) con los profesores. Las fechas de las entrevistas se publicarán con cierta antelación en el Campus Virtual.
# - Proporcionaremos un conjunto de casos de prueba preliminares (varios problemas) que deben resolverse correctamente. En caso contrario, el trabajo se considerará suspenso.
# - Para obtener una puntuación en el trabajo tendrás que responder, de forma individual, a una serie de preguntas sobre la organización del código y sobre cuestiones relacionadas.
# - En la evaluación no continua requeriremos la implementación de las mismas estrategias de búsqueda más estas dos adicionales: Búsqueda en profundidad limitada y Búsqueda en profundidad iterativa. También se pueden requerir características adicionales.
